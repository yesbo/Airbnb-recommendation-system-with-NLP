# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

# %%
listings = pd.read_csv('listings 2.csv')
listings.head(5)
# Out:
# /Users/wyn/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (43,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#      id                        listing_url       scrape_id last_scraped  \
# 0  2515  https://www.airbnb.com/rooms/2515  20180908060534   2018-09-08
# 1  2539  https://www.airbnb.com/rooms/2539  20180908060534   2018-09-08
# 2  2595  https://www.airbnb.com/rooms/2595  20180908060534   2018-09-08
# 3  3330  https://www.airbnb.com/rooms/3330  20180908060534   2018-09-08
# 4  3647  https://www.airbnb.com/rooms/3647  20180908060534   2018-09-08
#
#                                   name  \
# 0     Stay at Chez Chic budget room #1
# 1   Clean & quiet apt home by the park
# 2                Skylit Midtown Castle
# 3   ++ Brooklyn Penthouse Guestroom ++
# 4  THE VILLAGE OF HARLEM....NEW YORK !
#
# ...

# %%
#no missing values
amen = listings.amenities
len(amen)-amen.count()
# Out:
# 0

# %%
listings['amenities'].isnull().sum()
# Out:
# 0

# %%
amenities = listings['amenities']
amenities.str.strip()
for i in range(len(amenities)):
    amenities.at[i] = amenities[i].replace('{','').replace('}','').replace('"', '').replace(' ','_')

# %%
amenities[0:20]
# Out:
# 0     TV,Cable_TV,Internet,Wifi,Air_conditioning,Kit...
# 1     TV,Cable_TV,Internet,Wheelchair_accessible,Kit...
# 2     TV,Wifi,Air_conditioning,Kitchen,Paid_parking_...
# 3     TV,Internet,Wifi,Wheelchair_accessible,Kitchen...
# 4     Cable_TV,Internet,Wifi,Air_conditioning,Kitche...
# 5     TV,Cable_TV,Internet,Wifi,Air_conditioning,Kit...
# 6     Internet,Wifi,Kitchen,Breakfast,Heating,Smoke_...
# 7     Internet,Wifi,Air_conditioning,Kitchen,Elevato...
# 8     TV,Cable_TV,Internet,Wifi,Kitchen,Buzzer/wirel...
# 9     Wifi,Air_conditioning,Kitchen,Pets_live_on_thi...
# 10    Wifi,Air_conditioning,Kitchen,Paid_parking_off...
# 11    TV,Wifi,Air_conditioning,Paid_parking_off_prem...
# 12    Internet,Wifi,Air_conditioning,Paid_parking_of...
# 13    TV,Cable_TV,Internet,Wifi,Air_conditioning,Kit...
# 14    TV,Cable_TV,Wifi,Air_conditioning,Kitchen,Free...
# 15    Internet,Wifi,Air_conditioning,Kitchen,Doorman...
# 16    Internet,Wifi,Air_conditioning,Breakfast,Buzze...
# ...

# %%
Processed_Data = pd.DataFrame(data = listings['host_is_superhost'])

# %%
elements = []
sets = set()
for i in range(len(amenities)):
    for field in amenities[i].split(','):
        if field == '':
            continue
        else:
            sets.add('amenities_' + field)

#print(sets)   

#property_type_df = pd.DataFrame(0, columns = listings['property_type'].unique()[:-1], index = range(Processed_Data.shape[0]))

df_amenities = pd.DataFrame(0, columns=list(sets), index=range(Processed_Data.shape[0]))
len(sets)
df_amenities.shape
# Out:
# (50220, 125)

# %%
sets
# Out:
# {'amenities_24-hour_check-in',
#  'amenities_Accessible-height_bed',
#  'amenities_Accessible-height_toilet',
#  'amenities_Air_conditioning',
#  'amenities_Air_purifier',
#  'amenities_BBQ_grill',
#  'amenities_Baby_bath',
#  'amenities_Baby_monitor',
#  'amenities_Babysitter_recommendations',
#  'amenities_Bathtub',
#  'amenities_Bathtub_with_bath_chair',
#  'amenities_Beach_essentials',
#  'amenities_Beachfront',
#  'amenities_Bed_linens',
#  'amenities_Breakfast',
#  'amenities_Building_staff',
#  'amenities_Buzzer/wireless_intercom',
#  'amenities_Cable_TV',
#  'amenities_Carbon_monoxide_detector',
#  'amenities_Cat(s)',
#  'amenities_Ceiling_hoist',
#  'amenities_Changing_table',
#  'amenities_Children’s_books_and_toys',
#  'amenities_Children’s_dinnerware',
#  'amenities_Cleaning_before_checkout',
#  'amenities_Coffee_maker',
#  'amenities_Cooking_basics',
#  'amenities_Crib',
#  'amenities_Disabled_parking_spot',
#  'amenities_Dishes_and_silverware',
# ...

# %%
#count = 0
for s in sets:
    #count +=1
    #print(s[10:])
    for i in range(len(amenities)):
        for field in amenities[i].split(','):
            #print(field)
            if field == s[10:]:
                
                df_amenities[s][i] = 1
df_amenities.sum()
# Out:
# amenities_Oven                                          10152
# amenities_Coffee_maker                                   8901
# amenities_Other_pet(s)                                    123
# amenities_Safety_card                                    5686
# amenities_Ground_floor_access                              12
# amenities_Bathtub_with_bath_chair                          84
# amenities_Pool_with_pool_hoist                              7
# amenities_Heating                                       46126
# amenities_Kitchen                                       46518
# amenities_Beachfront                                       58
# amenities_Doorman                                        2982
# amenities_Bed_linens                                    10808
# amenities_Fixed_grab_bars_for_shower                      124
# amenities_Essentials                                    45567
# amenities_Pool                                            735
# ...
